# %%
from pathlib import Path

import pandas as pd
import numpy as np
import re
import regex
from pprint import pprint

import sys
src_path = str(Path.cwd().parent / "src")
sys.path.append(src_path)

import csv

# %% [markdown]
# # Load data

# %% [markdown]
# Read the csv file (first row contains the column names), specify the data types.

# %%
csv_dir = Path.cwd().parent / "speeches_csv" 
speeches_path = csv_dir / "all_speeches.txt"
dtypes={'title':'string', 'pages':'int64', 'date':'string', 'location':'string', 
        'highest_speaker_count':'int64', 'content':'string'}
df = pd.read_csv(speeches_path, header=0, dtype=dtypes)
df.head()
# Out:
#                                 title  pages               date  \
# 0                            CGI_2013     19  24 September 2013
# 1               Prayer_Breakfast_2016      7    4 February 2016
# 2          Security_Team_Announcement      5    1 December 2008
# 3                    Cairo_University     14        4 June 2009
# 4  Umpqua_Community_College_Shootings      4     1 October 2015
#
#                                             location  highest_speaker_count  \
# 0  Sheraton New York Hotel and Towers, New York, ...                     10
# 1                Washington Hilton, Washington, D.C.                      0
# 2                                  Chicago, Illinois                      0
# 3                                       Cairo, Egypt                      0
# 4                                   Washington, D.C.                      0
#
#                                              content
# 0  Hillary Clinton: Thank you very much. I have t...
# 1  Well, good morning. Giving all praise and hono...
# 2  Good morning, everybody. I hope you all had a ...
# 3  Thank you so much. Good afternoon. I am honore...
# 4  There's been another mass shooting in America ...

# %%
df.dtypes
# Out:
# title                    string
# pages                     int64
# date                     string
# location                 string
# highest_speaker_count     int64
# content                  string
# dtype: object

# %% [markdown]
# # Dates

# %% [markdown]
# Some dates had the year missing. The years for several speeches were wrong due to typos.

# %%
temp = df.loc[:, ['title','date']]
temp['has_year'] = temp.apply(lambda row: row['date'][-4:].isnumeric(), axis=1)
temp.loc[temp.has_year==False, :]
# Out:
#                                   title          date  has_year
# 256  Recovery_and_Reinvestment_Act_2016  26 February      False
# 265    Post_Iran_Nuclear_Accord_Presser      15 July      False

# %% [markdown]
# Edit the dates that need to be corrected.

# %%
titles = ['Community_College_Plan', 'Recovery_and_Reinvestment_Act_2016', 'Post_Iran_Nuclear_Accord_Presser', 
          'Hispanic_Chamber_of_Commerce', 'Iraq_and_Ukraine', 'Barack_Obama_-_Weekly_Address_01-01-16']
dates = ['9 January 2015', '26 February 2016', '15 July 2015', '10 March 2009', '28 August 2014', 
         '1 January 2016']

for i in range(len(titles)):
    print(df.loc[df.title==titles[i],'date'])
    df.loc[df.title==titles[i],'date'] = dates[i]
    print(df.loc[df.title==titles[i],'date'], '\n')
# Out:
# 78    9 January 20105
# Name: date, dtype: string
# 78    9 January 2015
# Name: date, dtype: string
#
# 256    26 February
# Name: date, dtype: string
# 256    26 February 2016
# Name: date, dtype: string
#
# 265    15 July
# Name: date, dtype: string
# 265    15 July 2015
# Name: date, dtype: string
#
# 352    10 March 2010
# Name: date, dtype: string
# 352    10 March 2009
# Name: date, dtype: string
#
# 217    29 August 2014
# Name: date, dtype: string
# 217    28 August 2014
# Name: date, dtype: string
#
# 335    1 January 2015
# Name: date, dtype: string
# 335    1 January 2016
# Name: date, dtype: string

# %% [markdown]
# Parse the dates.

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True, format="%d %B %Y")
df.head()
# Out:
#                                 title  pages       date  \
# 0                            CGI_2013     19 2013-09-24
# 1               Prayer_Breakfast_2016      7 2016-02-04
# 2          Security_Team_Announcement      5 2008-12-01
# 3                    Cairo_University     14 2009-06-04
# 4  Umpqua_Community_College_Shootings      4 2015-10-01
#
#                                             location  highest_speaker_count  \
# 0  Sheraton New York Hotel and Towers, New York, ...                     10
# 1                Washington Hilton, Washington, D.C.                      0
# 2                                  Chicago, Illinois                      0
# 3                                       Cairo, Egypt                      0
# 4                                   Washington, D.C.                      0
#
#                                              content
# 0  Hillary Clinton: Thank you very much. I have t...
# 1  Well, good morning. Giving all praise and hono...
# 2  Good morning, everybody. I hope you all had a ...
# 3  Thank you so much. Good afternoon. I am honore...
# 4  There's been another mass shooting in America ...

# %% [markdown]
# The `date` column now has type `datetime`.

# %%
df.dtypes
# Out:
# title                            string
# pages                             int64
# date                     datetime64[ns]
# location                         string
# highest_speaker_count             int64
# content                          string
# dtype: object

# %% [markdown]
# # Locations

# %% [markdown]
# Locations that specify a specific place in the White House can be replaced by `White House, Washington D.C.`.

# %%
contains_WH = df.location.str.contains("White House", flags=re.I)
df.loc[contains_WH, 'location'] = "White House, Washington D.C."

# %% [markdown]
# Make a `country`column, values for `White House` can already be filled.

# %%
df.loc[contains_WH, 'country'] = "USA"
df.loc[~contains_WH, 'country'] = ""

# %% [markdown]
# Set country to `USA` for locations that contain state names or state abbreviations. In case it contains the abbreviation, replace it by the full state name.

# %%
states_full = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming']
states_abbr = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

for state in states_full:
    contains = df.location.str.contains(state, flags=re.I)
    df.loc[contains, 'country'] = "USA"
    
for i in range(len(states_abbr)):
    contains = df.location.str.contains(r", \b"+states_abbr[i]+r"\b", flags=re.I)
    df.loc[contains, 'country'] = "USA"
    df['location'] = df.location.str.replace(
        r", \b"+states_abbr[i]+r"\b", repl=", "+states_full[i], flags=re.I, regex=True)

# %%
df.loc[df.country=="USA", :]
# Out:
#                                        title  pages       date  \
# 0                                   CGI_2013     19 2013-09-24
# 1                      Prayer_Breakfast_2016      7 2016-02-04
# 2                 Security_Team_Announcement      5 2008-12-01
# 4         Umpqua_Community_College_Shootings      4 2015-10-01
# 5      White_House_Correspondent_Dinner_2013      6 2013-04-27
# ..                                       ...    ...        ...
# 421                                 VFW_2012      9 2012-07-23
# 423            Wakefield_Back_to_High_School      7 2009-09-08
# 424                         CIA_First_Speech      5 2009-04-20
# 429  Second_Democratic_Nomination_Acceptance      9 2012-09-06
# 434     Oval_Office_Counter_Terrorism_Agenda      5 2015-12-06
#
#                                               location  highest_speaker_count  \
# 0    Sheraton New York Hotel and Towers, New York, ...                     10
# 1                  Washington Hilton, Washington, D.C.                      0
# 2                                    Chicago, Illinois                      0
# 4                                     Washington, D.C.                      0
# 5            Washington Hilton Hotel, Washington, D.C.                      0
# ..                                                 ...                    ...
# 421                                       Reno, Nevada                      0
# 423                                Arlington, Virginia                      0
# 424                                  Langley, Virginia                      1
# 429                          Charlotte, North Carolina                      0
# 434                       White House, Washington D.C.                      0
#
#                                                content country
# 0    Hillary Clinton: Thank you very much. I have t...     USA
# 1    Well, good morning. Giving all praise and hono...     USA
# 2    Good morning, everybody. I hope you all had a ...     USA
# 4    There's been another mass shooting in America ...     USA
# 5    Thank you. Thank you, everybody. How do you li...     USA
# ..                                                 ...     ...
# 421  Thank you! Hello VFW! Thank you so much. Pleas...     USA
# 423  Hello, everybody! Thank you. Thank you. Thank ...     USA
# 424  Thank you for the extraordinary welcome. And t...     USA
# 429  Thank you, so much. Thank you. Thank you very ...     USA
# 434  Good evening. On Wednesday, 14 Americans were ...     USA
#
# [263 rows x 7 columns]

# %%
df.loc[(df.country!="USA") & (df.location!="unknown_location"), :]
# Out:
#                                 title  pages       date  \
# 3                    Cairo_University     14 2009-06-04
# 14      PM_Abe_of_Japan_Joint_Presser     14 2014-04-24
# 15       UN_Copenhagen_Climate_Change      3 2009-12-18
# 16                   People_of_Greece     15 2016-11-16
# 17          India_Speech_at_New_Delhi      9 2015-01-27
# ..                                ...    ...        ...
# 409              Saudi_Arabia_Presser      6 2005-04-21
# 426  Hiroshima_Peace_Memorial_Address      5 2016-05-27
# 430             Shimon_Peres_Memorial      6 2016-09-30
# 431               ASEAN_Business_2015      9 2015-11-21
# 433                    YLAI_Town_Hall     22 2016-03-23
#
#                                               location  highest_speaker_count  \
# 3                                         Cairo, Egypt                      0
# 14                        Akasaka Palace, Tokyo, Japan                     10
# 15                                 Copenhagen, Denmark                      0
# 16   Stavros Niarchos Foundation Cultural Center, A...                      0
# 17              Siri Fort Auditorium, New Delhi, India                      0
# ..                                                 ...                    ...
# 409               Diriyah Palace, Riyadh, Saudi Arabia                      5
# 426                                   Hiroshima, Japan                      0
# 430                     Mount Herzl, Jerusalem, Israel                      0
# 431           Shangri-La Hotel, Kuala Lumpur, Malaysia                      0
# 433            Usina Del Arte, Buenos Aires, Argentina                     25
#
#                                                content country
# 3    Thank you so much. Good afternoon. I am honore...
# 14   Prime Minister Abe: As interpreted. On behalf ...
# 15   Good morning. It is an honor for me to join th...
# 16   Hello, Greece! Yia sas! Kalispera! Good evenin...
# 17   Thank you so much. Thank you so much, Neha, fo...
# ..                                                 ...     ...
# 409  President Obama: You already heard my statemen...
# 426  Seventy-one years ago, on a bright, cloudless ...
# 430  Zvia, Yoni, Chemi and generations of the Peres...
# 431  Thank you so much. Please be seated. Well, goo...
# 433  Hola! Thank you. Thank you so much. Muchas gra...
#
# [84 rows x 7 columns]

# %% [markdown]
# Change `Washington, D.C.` (and some variations) to `Washington D.C.`.

# %%
df['location'] = df.location.str.replace("Washington, D.?C.?", repl="Washington D.C.", flags=re.I, regex=True)

# %% [markdown]
# If `country=='USA'`: We assume the last substring to be the state, the second to last the city and everything before that a more specific locations.
#
#
# If `country!='USA'`: We assume the last substring to be the country, the second to last the city and everything before that a more specific locations.

# %%
df.loc[:, 'count_commas'] = df.loc[:, 'location'].str.count(',')
df.loc[:,['location','country','count_commas']].sort_values(by='count_commas')
# Out:
#                                               location country  count_commas
# 217                                   unknown_location                     0
# 181                                    Washington D.C.     USA             0
# 189                                   unknown_location                     0
# 198                                   unknown_location                     0
# 199               James L. Knight International Center                     0
# ..                                                 ...     ...           ...
# 246  Phillips Center for the Performing Arts, Orlan...     USA             2
# 245          JFK Space Center, Merritt Island, Florida     USA             2
# 316                      Gostinny Dvor, Moscow, Russia                     2
# 0    Sheraton New York Hotel and Towers, New York, ...     USA             2
# 261  Lindley Hall, Royal Horticulture Halls, London...                     3
#
# [436 rows x 3 columns]

# %% [markdown]
# ## USA

# %% [markdown]
# ### No commas

# %%
print(df.loc[(df.country=="USA") & (df.count_commas == 0), ['title','location']].sort_values(by='location'), '\n')

df.loc[df.title=='Ebola_CDC', ['state','city','specific_location']] = ['Georgia', 'Atlanta', 'no_specific_location']
df.loc[df.location=='Washington D.C.', ['state','city','specific_location']] = ['no_state', 'Washington D.C.', 
                                                                                'no_specific_location']
# Out:
#                                       title         location
# 308                               Ebola_CDC  Atlanta Georgia
# 258                 State_of_the_Union_2012  Washington D.C.
# 278                 Health_Care_Law_Signing  Washington D.C.
# 284  White_House_Correspondents_Dinner_2015  Washington D.C.
# 285                 Paris_Terrorist_Attacks  Washington D.C.
# 288                     Brookings_Institute  Washington D.C.
# 293   Go_Presidential_Election_Outcome_2016  Washington D.C.
# 298          Howard_University_Commencement  Washington D.C.
# 4        Umpqua_Community_College_Shootings  Washington D.C.
# 314      National_Holocaust_Memorial_Museum  Washington D.C.
# 321     Iftar_Dinner_on_Religious_Tolerance  Washington D.C.
# 322   Second_Presidential_Inaugural_Address  Washington D.C.
# 330   White_House_Correspondent_Dinner_2014  Washington D.C.
# 356              Syria_Speech_to_the_Nation  Washington D.C.
# 370        Final_State_of_the_Union_Address  Washington D.C.
# 371                        Lincoln_Memorial  Washington D.C.
# 234        Naturalization_National_Archives  Washington D.C.
# 215                   Prayer_Breakfast_2011  Washington D.C.
# 203               Senate_Floor_Coretta_King  Washington D.C.
# 181            National_Chamber_of_Commerce  Washington D.C.
# 7           Senate_Floor_Immigration_Reform  Washington D.C.
# 13            Holocaust_Days_of_Remembrance  Washington D.C.
# 22                    Prayer_Breakfast_2014  Washington D.C.
# 33        Joint_Session_on_Economy_and_Jobs  Washington D.C.
# 62   White_House_Correspondents_Dinner_2011  Washington D.C.
# 63            Iran_Deal_American_University  Washington D.C.
# 73                   Iraq_War_After_4_Years  Washington D.C.
# 401                              Rosa_Parks  Washington D.C.
# 81                  State_of_the_Union_2011  Washington D.C.
# 93                    Chicago_Cubs_WH_Visit  Washington D.C.
# 100    Senate_Speech_on_Ohio_Electoral_Vote  Washington D.C.
# 112              Congressional_Black_Caucus  Washington D.C.
# 120                          Oval_Office_BP  Washington D.C.
# 139                           VOX_Interview  Washington D.C.
# 145                 State_of_the_Union_2010  Washington D.C.
# 148               Hurricane_Sandy_Red_Cross  Washington D.C.
# 88                  State_of_the_Union_2013  Washington D.C.
# 417               Birth_Certificate_Release  Washington D.C.

# %% [markdown]
# ### One comma + `Washington D.C.`

# %%
contains_WDC = df.location.str.contains("Washington D.C.", flags=re.I)
select = contains_WDC & (df.count_commas == 1)
print(df.loc[select, 'location'])

locations = df.loc[select, 'location'].str.extract(r"(.+), Washington D.C. *", flags=re.I)

df.loc[select, ['state','city']]  = ['no_state', 'Washington D.C.']
df.loc[select, 'specific_location'] = locations.values
# Out:
# 1               Washington Hilton, Washington D.C.
# 5         Washington Hilton Hotel, Washington D.C.
# 8                     White House, Washington D.C.
# 11                    White House, Washington D.C.
# 12                    White House, Washington D.C.
#                           ...
# 414                   White House, Washington D.C.
# 415              State Department, Washington D.C.
# 416           Eisenhower Building, Washington D.C.
# 418    U.S. Capitol Western Front, Washington D.C.
# 434                   White House, Washington D.C.
# Name: location, Length: 106, dtype: string

# %% [markdown]
# ### One comma + other

# %%
select = (df.country=="USA") & ~contains_WDC & (df.count_commas == 1)
print(df.loc[select, 'location'])

states = df.loc[select, 'location'].str.extract(r".+?, *(.+)", flags=re.I)
cities = df.loc[select, 'location'].str.extract(r"(.+?), *.+", flags=re.I)

df.loc[select, 'state']  = states.values
df.loc[select, 'city']  = cities.values
df.loc[select, 'specific_location'] = 'no_specific_location'
# Out:
# 2              Chicago, Illinois
# 10          San Jose, California
# 20             Fairfax, Virginia
# 28             Beaverton, Oregon
# 31                Kailua, Hawaii
#                  ...
# 420          Arlington, Virginia
# 421                 Reno, Nevada
# 423          Arlington, Virginia
# 424            Langley, Virginia
# 429    Charlotte, North Carolina
# Name: location, Length: 73, dtype: string

# %%
df.loc[select, ['location','country','state','city','specific_location']].sort_values(
    by= ['state','city','specific_location'])
# Out:
#                                           location country          state  \
# 61                                Alberta, Alabama     USA        Alabama
# 227  Hilton San Francisco Union Square, California     USA     California
# 163                      Rancho Mirage, California     USA     California
# 224                      Rancho Mirage, California     USA     California
# 10                            San Jose, California     USA     California
# ..                                             ...     ...            ...
# 153       Joint Base Myer-Henderson Hall, Virginia     USA       Virginia
# 242                              Langley, Virginia     USA       Virginia
# 424                              Langley, Virginia     USA       Virginia
# 204                               McLean, Virginia     USA       Virginia
# 397                         Beckley, West Virginia     USA  West Virginia
#
#                                   city     specific_location
# 61                             Alberta  no_specific_location
# 227  Hilton San Francisco Union Square  no_specific_location
# 163                      Rancho Mirage  no_specific_location
# 224                      Rancho Mirage  no_specific_location
# 10                            San Jose  no_specific_location
# ..                                 ...                   ...
# 153     Joint Base Myer-Henderson Hall  no_specific_location
# 242                            Langley  no_specific_location
# 424                            Langley  no_specific_location
# 204                             McLean  no_specific_location
# 397                            Beckley  no_specific_location
#
# [73 rows x 5 columns]

# %% [markdown]
# Some cities need corrections. Cities that don't have a space in them are all ok, we only need to look at ones with spaces.

# %%
contains = df.loc[select, 'city'].str.contains(" ", flags=re.I)
df.loc[select & contains, ['title', 'location','state','city','specific_location']].sort_values(
    by= ['state','city','specific_location'])
# Out:
#                                              title  \
# 227                         Mayors_Conference_2015
# 163                              ASEAN_Summit_2016
# 224                         Antonin_Scalia_Passing
# 10   Affordable_Care_Act_and_Domestic_Surveillance
# 174        White_House_Correspondents_Dinner_First
# 400                              Beau_Biden_Eulogy
# 191                            Gun_Violence_Denver
# 241    Second_Presidential_Election_Victory_Speech
# 247                     Iowa_Caucus_Victory_Speech
# 319                Joplin_Tornado_Victims_Memorial
# 337                           Baton_Rouge_Flooding
# 180                           Grande_Isle_Briefing
# 104                           Energy_Security_AAFB
# 46                            Worldwide_Troop_Talk
# 260               Farewell_to_Staff_and_Supporters
# 77                      American_Legion_Conference
# 169                             Nomination_Victory
# 49                                       UNGA_2012
# 64                               UNGA_68th_Session
# 150           United_Nations_Security_Council_2014
# 156                               UN_Ebola_Meeting
# 183                         United_Nations_GA_2016
# 211                   Barnard_College_Commencement
# 255           United_Nations_General_Assembly_2014
# 271        United_Nations_on_Palestinian_Statehood
# 392                            UN_High_Level_Libya
# 396                United_Nations_General_Assembly
# 398                                      UNGA_2010
# 214          US_Military_Academy_Commencement_2014
# 354                          Iraq_War_Camp_Lejeune
# 419                             Fort_Hoot_Memorial
# 153                      Martin_Dempsey_Retirement
#
#                                              location             state  \
# 227     Hilton San Francisco Union Square, California        California
# 163                         Rancho Mirage, California        California
# 224                         Rancho Mirage, California        California
# 10                               San Jose, California        California
# 174                     Washington Hilton Hotel, D.C.              D.C.
# 400  St. Anthony of Padua Church Wilmington, Delaware          Delaware
# 191           Denver Police Academy, Denver. Colorado  Denver. Colorado
# 241                 McCormick Place Chicago, Illinois          Illinois
# 247                                  Des Moines, Iowa              Iowa
# 319     Missouri Southern University, Joplin Missouri   Joplin Missouri
# 337                            Baton Rouge, Louisiana         Louisiana
# 180                            Grande Isle, Louisiana         Louisiana
# 104                            Camp Springs, Maryland          Maryland
# 46                               Fort Meade, Maryland          Maryland
# 260                    Prince George County, Maryland          Maryland
# 77           Minneapolis Convention Center, Minnesota         Minnesota
# 169                               St. Paul, Minnesota         Minnesota
# 49                                 New York, New York          New York
# 64                                 New York, New York          New York
# 150                                New York, New York          New York
# 156                                New York, New York          New York
# 183                                New York, New York          New York
# 211                                New York, New York          New York
# 255                                New York, New York          New York
# 271                                New York, New York          New York
# 392                                New York, New York          New York
# 396                                New York, New York          New York
# 398                                New York, New York          New York
# 214                              West Point, New York          New York
# 354                      Camp Lejeune, North Carolina    North Carolina
# 419                                  Fort Hood, Texas             Texas
# 153          Joint Base Myer-Henderson Hall, Virginia          Virginia
#
#                                        city     specific_location
# 227       Hilton San Francisco Union Square  no_specific_location
# 163                           Rancho Mirage  no_specific_location
# 224                           Rancho Mirage  no_specific_location
# 10                                 San Jose  no_specific_location
# 174                 Washington Hilton Hotel  no_specific_location
# 400  St. Anthony of Padua Church Wilmington  no_specific_location
# 191                   Denver Police Academy  no_specific_location
# 241                 McCormick Place Chicago  no_specific_location
# 247                              Des Moines  no_specific_location
# 319            Missouri Southern University  no_specific_location
# 337                             Baton Rouge  no_specific_location
# 180                             Grande Isle  no_specific_location
# 104                            Camp Springs  no_specific_location
# 46                               Fort Meade  no_specific_location
# 260                    Prince George County  no_specific_location
# 77            Minneapolis Convention Center  no_specific_location
# 169                                St. Paul  no_specific_location
# 49                                 New York  no_specific_location
# 64                                 New York  no_specific_location
# 150                                New York  no_specific_location
# 156                                New York  no_specific_location
# 183                                New York  no_specific_location
# 211                                New York  no_specific_location
# 255                                New York  no_specific_location
# 271                                New York  no_specific_location
# 392                                New York  no_specific_location
# 396                                New York  no_specific_location
# 398                                New York  no_specific_location
# 214                              West Point  no_specific_location
# 354                            Camp Lejeune  no_specific_location
# 419                               Fort Hood  no_specific_location
# 153          Joint Base Myer-Henderson Hall  no_specific_location

# %%
need_corrections = ['Mayors_Conference_2015','White_House_Correspondents_Dinner_First','Beau_Biden_Eulogy',
                   'Gun_Violence_Denver','Second_Presidential_Election_Victory_Speech','Joplin_Tornado_Victims_Memorial',
                   'American_Legion_Conference','Iraq_War_Camp_Lejeune','Martin_Dempsey_Retirement']

states = ['California', 'no_state', 'Delaware', 'Colorado', 'Illinois', 'Missouri', 'Minnesota', 'North Carolina', 
          'Virginia']
cities = ['San Francisco', 'Washington D.C.', 'Wilmington', 'Denver', 'Chicago', 'Joplin', 'Minneapolis', 'Jacksonville', 
          'Arlington']
locations = ['Hilton San Francisco Union Square Hotel', 'Washington Hilton Hotel', 'St. Anthony of Padua Church', 
             'Denver Police Academy', 'McCormick Place', 'Missouri Southern University', 'Minneapolis Convention Center', 
             'Camp Lejeune', 'Joint Base Myer-Henderson Hall']

df.loc[df.title.isin(need_corrections), 'state'] = states
df.loc[df.title.isin(need_corrections), 'city'] = cities
df.loc[df.title.isin(need_corrections), 'specific_location'] = locations
df.loc[df.title.isin(need_corrections), ['location','state','city','specific_location']].sort_values(
    by= ['state','city','specific_location'])
# Out:
#                                              location           state  \
# 77           Minneapolis Convention Center, Minnesota      California
# 191           Denver Police Academy, Denver. Colorado        Colorado
# 174                     Washington Hilton Hotel, D.C.        Delaware
# 227     Hilton San Francisco Union Square, California        Illinois
# 319     Missouri Southern University, Joplin Missouri       Minnesota
# 241                 McCormick Place Chicago, Illinois        Missouri
# 354                      Camp Lejeune, North Carolina  North Carolina
# 400  St. Anthony of Padua Church Wilmington, Delaware        Virginia
# 153          Joint Base Myer-Henderson Hall, Virginia        no_state
#
#                 city                        specific_location
# 77     San Francisco  Hilton San Francisco Union Square Hotel
# 191           Denver                    Denver Police Academy
# 174       Wilmington              St. Anthony of Padua Church
# 227          Chicago                          McCormick Place
# 319      Minneapolis            Minneapolis Convention Center
# 241           Joplin             Missouri Southern University
# 354     Jacksonville                             Camp Lejeune
# 400        Arlington           Joint Base Myer-Henderson Hall
# 153  Washington D.C.                  Washington Hilton Hotel

# %% [markdown]
# ### Two commas

# %%
select = (df.country=="USA") & (df.count_commas == 2)
print(df.loc[select, 'location'])

states = df.loc[select, 'location'].str.extract(r".+?,.+?, *(.+)", flags=re.I)
cities = df.loc[select, 'location'].str.extract(r".+?, *(.+?),.+", flags=re.I)
locations = df.loc[select, 'location'].str.extract(r" *(.+?),.+?,.+", flags=re.I)

df.loc[select, 'state']  = states.values
df.loc[select, 'city']  = cities.values
df.loc[select, 'specific_location'] = locations.values
# Out:
# 0      Sheraton New York Hotel and Towers, New York, ...
# 24          Harborside Event Center, Fort Myers, Florida
# 26              Kaneohe Bay Marine Base, Kaneohe, Hawaii
# 38        Veterans Memorial Auditorium, Des Moines, Iowa
# 53     Newport News Shipbuilding, Newport News, Virginia
# 56                    McCormick Place, Chicago, Illinois
# 65               Hofstra University, Hempstead, New York
# 71                         Del Sol HS, Las Vegas, Nevada
# 78     Pellissippi State Community College, Knoxville...
# 80          Lyndon Baines Johnson Library, Austin, Texas
# 92                    Lincoln Center, New York, New York
# 99                         Pentagon, Arlington, Virginia
# 102       Joint Base Myer-Henderson, Fort Myer, Virginia
# 106    Philadelphia Convention Center, Philadelphia, ...
# 107                    Sun Devil Stadium, Tempe, Arizona
# 109        Illinois State Capitol, Springfield, Illinois
# 111          Hyde Park Career Academy, Chicago, Illinois
# 137     Arlington National Cemetery, Arlington, Virginia
# 144           Macomb Community College, Warren, Michigan
# 147                     Hyatt Regency, Chicago, Illinois
# 158                    University of Baylor, Waco, Texas
# 164    East End Family Community Center, Charleston, ...
# 190                 Lynn University, Boca Raton, Florida
# 219                 Michie Stadium, West Point, New York
# 220    United States Air Force Academy, Colorado Spri...
# 225    Carnegie Mellon University, Pittsburgh, Pennsy...
# 237        Magness Arena, University of Denver, Colorado
# 245            JFK Space Center, Merritt Island, Florida
# 246    Phillips Center for the Performing Arts, Orlan...
# 259               MacDill Air Force Base, Tampa, Florida
# 289    Lotte New York Palace Hotel, New York City, Ne...
# 310                  UN Headquarters, New York, New York
# 312    Andrew Sanchez Community Center, New Orleans, ...
# 325    University of Chicago Law School, Chicago, Ill...
# 326    Eisenhower Hall, West Point Military Academy, ...
# 327    Georgia Institute of Technology, Atlanta, Georgia
# 331         Southern Methodist University, Dallas, Texas
# 336       Long Center for Performing Arts, Austin, Texas
# 346            Northwestern High School, Flint, Michigan
# 367                 Edmund Pettus Bridge, Selma, Alabama
# 368                     Cooper Union, New York, New York
# 376    McKale Memorial Center, University of Arizona,...
# 380    College of Charleston, Charleston, South Carolina
# 381            Stanford University, Stanford, California
# 382    West Virginia State Capitol, Charleston, West ...
# 412    Northern Michigan University, Marquette, Michigan
# Name: location, dtype: string

# %%
df.loc[select, ['title','location','state','city','specific_location']].sort_values(
    by= ['state','city','specific_location'])
# Out:
#                                           title  \
# 367                              Selma_50_March
# 107                            ASU_Commencement
# 381               Stanford_Cybersecurity_Summit
# 220            US_Air_Force_Commencement_Speech
# 237            Obama-Romney_-_First_Live_Debate
# 190            Obama-Romney_-_Third_Live_Debate
# 24                               Aurora_Tragedy
# 245                           NASA_21st_Century
# 246                           Orlando_Community
# 259           On_Counterterrorism_Approach_2016
# 327                  Student_Aid_Bill_of_Rights
# 26                         NW_Flight_253_Update
# 147                American_Medical_Association
# 111                        Middle_Class_Economy
# 56                             Farewell_Address
# 325            University_of_Chicago_Law_School
# 109                   Illinois_General_Assembly
# 38      Barack_Obama_-_Jefferson-Jackson_Dinner
# 312                            Katrina_10_Years
# 346                    Flint_Michigan_Community
# 412                National_Wireless_Initiative
# 144                       Graduation_Initiative
# 71       Comprehensive_Immigration_Reform_Vegas
# 65            Obama-Romney_-_Second_Live_Debate
# 368                       Reforming_Wall_Street
# 92                     Walter_Cronkite_Memorial
# 0                                      CGI_2013
# 310                      United_Nations_GA_2015
# 289                            NY_NJ_Explosions
# 219                West_Point_Commencement_2010
# 326                 Afghanistan_War_Troop_Surge
# 106                        NAACP_Coference_2015
# 225                    Carnegie_Robotics_Center
# 380                    Clementa_Pinckney_Eulogy
# 78                       Community_College_Plan
# 336                                        SXSW
# 80                      Civil_Rights_Summit_LBJ
# 331                      GWB_Library_Dedication
# 158            West_Fertilizer_Tragedy_Memorial
# 376                     Tucson_Memorial_Address
# 137                   Veterans_Day_Address_2013
# 99   ISIL_Presser_Post_Security_Council_Meeting
# 102                       Armed_Forces_Farewell
# 53                Sequester_Impact_Newport_News
# 164            Prescription_Drug_Abuse_Forum_WV
# 382                          Robert_Bryd_Eulogy
#
#                                               location           state  \
# 367               Edmund Pettus Bridge, Selma, Alabama         Alabama
# 107                  Sun Devil Stadium, Tempe, Arizona         Arizona
# 381          Stanford University, Stanford, California      California
# 220  United States Air Force Academy, Colorado Spri...        Colorado
# 237      Magness Arena, University of Denver, Colorado        Colorado
# 190               Lynn University, Boca Raton, Florida         Florida
# 24        Harborside Event Center, Fort Myers, Florida         Florida
# 245          JFK Space Center, Merritt Island, Florida         Florida
# 246  Phillips Center for the Performing Arts, Orlan...         Florida
# 259             MacDill Air Force Base, Tampa, Florida         Florida
# 327  Georgia Institute of Technology, Atlanta, Georgia         Georgia
# 26            Kaneohe Bay Marine Base, Kaneohe, Hawaii          Hawaii
# 147                   Hyatt Regency, Chicago, Illinois        Illinois
# 111        Hyde Park Career Academy, Chicago, Illinois        Illinois
# 56                  McCormick Place, Chicago, Illinois        Illinois
# 325  University of Chicago Law School, Chicago, Ill...        Illinois
# 109      Illinois State Capitol, Springfield, Illinois        Illinois
# 38      Veterans Memorial Auditorium, Des Moines, Iowa            Iowa
# 312  Andrew Sanchez Community Center, New Orleans, ...       Louisiana
# 346          Northwestern High School, Flint, Michigan        Michigan
# 412  Northern Michigan University, Marquette, Michigan        Michigan
# 144         Macomb Community College, Warren, Michigan        Michigan
# 71                       Del Sol HS, Las Vegas, Nevada          Nevada
# 65             Hofstra University, Hempstead, New York        New York
# 368                   Cooper Union, New York, New York        New York
# 92                  Lincoln Center, New York, New York        New York
# 0    Sheraton New York Hotel and Towers, New York, ...        New York
# 310                UN Headquarters, New York, New York        New York
# 289  Lotte New York Palace Hotel, New York City, Ne...        New York
# 219               Michie Stadium, West Point, New York        New York
# 326  Eisenhower Hall, West Point Military Academy, ...        New York
# 106  Philadelphia Convention Center, Philadelphia, ...    Pennsylvania
# 225  Carnegie Mellon University, Pittsburgh, Pennsy...    Pennsylvania
# 380  College of Charleston, Charleston, South Carolina  South Carolina
# 78   Pellissippi State Community College, Knoxville...       Tennessee
# 336     Long Center for Performing Arts, Austin, Texas           Texas
# 80        Lyndon Baines Johnson Library, Austin, Texas           Texas
# 331       Southern Methodist University, Dallas, Texas           Texas
# 158                  University of Baylor, Waco, Texas           Texas
# 376  McKale Memorial Center, University of Arizona,...          Tucson
# 137   Arlington National Cemetery, Arlington, Virginia        Virginia
# 99                       Pentagon, Arlington, Virginia        Virginia
# 102     Joint Base Myer-Henderson, Fort Myer, Virginia        Virginia
# 53   Newport News Shipbuilding, Newport News, Virginia        Virginia
# 164  East End Family Community Center, Charleston, ...   West Virginia
# 382  West Virginia State Capitol, Charleston, West ...   West Virginia
#
#                             city                        specific_location
# 367                        Selma                     Edmund Pettus Bridge
# 107                        Tempe                        Sun Devil Stadium
# 381                     Stanford                      Stanford University
# 220             Colorado Springs          United States Air Force Academy
# 237         University of Denver                            Magness Arena
# 190                   Boca Raton                          Lynn University
# 24                    Fort Myers                  Harborside Event Center
# 245               Merritt Island                         JFK Space Center
# 246                      Orlando  Phillips Center for the Performing Arts
# 259                        Tampa                   MacDill Air Force Base
# 327                      Atlanta          Georgia Institute of Technology
# 26                       Kaneohe                  Kaneohe Bay Marine Base
# 147                      Chicago                            Hyatt Regency
# 111                      Chicago                 Hyde Park Career Academy
# 56                       Chicago                          McCormick Place
# 325                      Chicago         University of Chicago Law School
# 109                  Springfield                   Illinois State Capitol
# 38                    Des Moines             Veterans Memorial Auditorium
# 312                  New Orleans          Andrew Sanchez Community Center
# 346                        Flint                 Northwestern High School
# 412                    Marquette             Northern Michigan University
# 144                       Warren                 Macomb Community College
# 71                     Las Vegas                               Del Sol HS
# 65                     Hempstead                       Hofstra University
# 368                     New York                             Cooper Union
# 92                      New York                           Lincoln Center
# 0                       New York       Sheraton New York Hotel and Towers
# 310                     New York                          UN Headquarters
# 289                New York City              Lotte New York Palace Hotel
# 219                   West Point                           Michie Stadium
# 326  West Point Military Academy                          Eisenhower Hall
# 106                 Philadelphia           Philadelphia Convention Center
# 225                   Pittsburgh               Carnegie Mellon University
# 380                   Charleston                    College of Charleston
# 78                     Knoxville      Pellissippi State Community College
# 336                       Austin          Long Center for Performing Arts
# 80                        Austin            Lyndon Baines Johnson Library
# 331                       Dallas            Southern Methodist University
# 158                         Waco                     University of Baylor
# 376        University of Arizona                   McKale Memorial Center
# 137                    Arlington              Arlington National Cemetery
# 99                     Arlington                                 Pentagon
# 102                    Fort Myer                Joint Base Myer-Henderson
# 53                  Newport News                Newport News Shipbuilding
# 164                   Charleston         East End Family Community Center
# 382                   Charleston              West Virginia State Capitol

# %% [markdown]
# Some cities need corrections.

# %%
need_corrections = ['Obama-Romney_-_First_Live_Debate', 'NY_NJ_Explosions', 'Afghanistan_War_Troop_Surge', 
                    'Tucson_Memorial_Address', 'Armed_Forces_Farewell']

states = ['Colorado', 'New York', 'New York', 'Arizona', 'Virginia']
cities = ['Denver', 'New York', 'West Point', 'Tucson', 'Arlington']
locations = ['University of Denver Magness Arena', 'Lotte New York Palace Hotel', 'Military Academy Eisenhower Hall', 
             'University of Arizona McKale Memorial Center', 'Fort Myer Joint Base Myer-Henderson']

df.loc[df.title.isin(need_corrections), 'state'] = states
df.loc[df.title.isin(need_corrections), 'city'] = cities
df.loc[df.title.isin(need_corrections), 'specific_location'] = locations
df.loc[df.title.isin(need_corrections), ['location','state','city','specific_location']].sort_values(
    by= ['state','city','specific_location'])
# Out:
#                                               location     state        city  \
# 326  Eisenhower Hall, West Point Military Academy, ...   Arizona      Tucson
# 102     Joint Base Myer-Henderson, Fort Myer, Virginia  Colorado      Denver
# 237      Magness Arena, University of Denver, Colorado  New York    New York
# 289  Lotte New York Palace Hotel, New York City, Ne...  New York  West Point
# 376  McKale Memorial Center, University of Arizona,...  Virginia   Arlington
#
#                                 specific_location
# 326  University of Arizona McKale Memorial Center
# 102            University of Denver Magness Arena
# 237                   Lotte New York Palace Hotel
# 289              Military Academy Eisenhower Hall
# 376           Fort Myer Joint Base Myer-Henderson

# %% [markdown]
# ### Result for locations in USA

# %%
df.loc[df.country=="USA", ['location','country','state','city','specific_location']].sort_values(
    by=['state','city','specific_location'])
# Out:
#                                               location country       state  \
# 61                                    Alberta, Alabama     USA     Alabama
# 367               Edmund Pettus Bridge, Selma, Alabama     USA     Alabama
# 107                  Sun Devil Stadium, Tempe, Arizona     USA     Arizona
# 326  Eisenhower Hall, West Point Military Academy, ...     USA     Arizona
# 163                          Rancho Mirage, California     USA  California
# ..                                                 ...     ...         ...
# 356                                    Washington D.C.     USA    no_state
# 370                                    Washington D.C.     USA    no_state
# 371                                    Washington D.C.     USA    no_state
# 401                                    Washington D.C.     USA    no_state
# 417                                    Washington D.C.     USA    no_state
#
#                 city                             specific_location
# 61           Alberta                          no_specific_location
# 367            Selma                          Edmund Pettus Bridge
# 107            Tempe                             Sun Devil Stadium
# 326           Tucson  University of Arizona McKale Memorial Center
# 163    Rancho Mirage                          no_specific_location
# ..               ...                                           ...
# 356  Washington D.C.                          no_specific_location
# 370  Washington D.C.                          no_specific_location
# 371  Washington D.C.                          no_specific_location
# 401  Washington D.C.                          no_specific_location
# 417  Washington D.C.                          no_specific_location
#
# [263 rows x 5 columns]

# %% [markdown]
# ## Not USA, but known location

# %% [markdown]
# Note: some US locations don't have `country=='USA'` yet

# %% [markdown]
# ### Zero commas

# %%
select = (df.country!="USA") & (df.location!="unknown_location") & (df.count_commas == 0)
df.loc[select, ['title','location']]
# Out:
#                                            title  \
# 44   Joint_Presser_with_President_Benigno_Aquino
# 114                    Benghazi_Remains_Transfer
# 168                               Berlin_Address
# 199              Miami_Dade_College_Commencement
# 200                         Strasbourg_Town_Hall
# 273                        Hradany_Square_Prague
# 348                          Hurricane_Sandy_ERT
#
#                                  location
# 44                                 Manila
# 114    James S. Brady Press Briefing Room
# 168                        Victory Column
# 199  James L. Knight International Center
# 200                   Rhenus Sports Arena
# 273                        Czech Republic
# 348    James S. Brady Press Briefing Room

# %%
titles = df.loc[select, 'title']
df.loc[df.title=='Joint_Presser_with_President_Benigno_Aquino', 
       ['country','state','city','specific_location']] = ['Philippines', 'no_state', 'Manila', 'no_specific_location']
df.loc[df.title=='Benghazi_Remains_Transfer', 
       ['country','state','city','specific_location']] = ['USA', 'no_state', 'Washington D.C.', 'White House']
df.loc[df.title=='Berlin_Address', 
       ['country','state','city','specific_location']] = ['Germany', 'no_state', 'Berlin', 'Victory Column']
df.loc[df.title=='Miami_Dade_College_Commencement', 
       ['country','state','city','specific_location']] = ['USA', 'Florida', 'Miami', 'James L. Knight International Center']
df.loc[df.title=='Strasbourg_Town_Hall', 
       ['country','state','city','specific_location']] = ['France', 'no_state', 'Strasbourg', 'Rhenus Sports Arena']
df.loc[df.title=='Hradany_Square_Prague', 
       ['country','state','city','specific_location']] = ['Czech Republic', 'no_state', 'Prague', 'Hradany Square']
df.loc[df.title=='Hurricane_Sandy_ERT', 
       ['country','state','city','specific_location']] = ['USA', 'no_state', 'Washington D.C.', 'White House']

df.loc[df.title.isin(titles), ['location','country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#                                  location         country     state  \
# 273                        Czech Republic  Czech Republic  no_state
# 200                   Rhenus Sports Arena          France  no_state
# 168                        Victory Column         Germany  no_state
# 44                                 Manila     Philippines  no_state
# 199  James L. Knight International Center             USA   Florida
# 114    James S. Brady Press Briefing Room             USA  no_state
# 348    James S. Brady Press Briefing Room             USA  no_state
#
#                 city                     specific_location
# 273           Prague                        Hradany Square
# 200       Strasbourg                   Rhenus Sports Arena
# 168           Berlin                        Victory Column
# 44            Manila                  no_specific_location
# 199            Miami  James L. Knight International Center
# 114  Washington D.C.                           White House
# 348  Washington D.C.                           White House

# %% [markdown]
# ### One comma

# %%
select = (df.country!="USA") & (df.location!="unknown_location") & (df.count_commas == 1)
titles = df.loc[select, 'title']
df.loc[select, ['title','location']]
# Out:
#                                        title  \
# 3                           Cairo_University
# 15              UN_Copenhagen_Climate_Change
# 21               Paris_Press_Conference_2015
# 25                          2004_DNC_Address
# 39                            Fort_Bonifacio
# 51                   Post_ASEAN_Presser_2016
# 52                     Post_G7_Presser_Japan
# 69                       Chile_Latin_America
# 79                         Jamaica_Town_Hall
# 94                         Yangon_University
# 115              Angela_Merkel_Joint_Presser
# 133             Afghanistan_US_Troops_Bagram
# 135                                YLAI_2016
# 151                    Peru_Press_Conference
# 161                           Rio_de_Janeiro
# 166            Bagram_Air_Base_December_2010
# 178                         Ebenezer_Baptist
# 192                    Queensland_University
# 208                       British_Parliament
# 223                 Shinzo_Abe_Presser_Japan
# 232               NATO_2016_Press_Conference
# 249                       Ted_Kennedy_Eulogy
# 262                     Indonesia_University
# 294                      Capetown_University
# 301                        Indian_Parliament
# 304                    Australian_Parliament
# 309                 Aung_San_Suu_Kyi_Presser
# 324                  Summit_Americas_Presser
# 333                    Post_G20_2016_Presser
# 334                  Summit_Americas_Plenary
# 340          Post_G7_Conference_Presser_2015
# 357  Jerusalem_Intl_Convention_Center_Speech
# 377                        Hankuk_University
# 378                       Turkish_Parliament
# 385                           Mexico_Address
# 389                           Estonia_People
# 393                  Dreamplex_Event_Address
# 403                                  DDay_65
# 426         Hiroshima_Peace_Memorial_Address
#
#                                         location
# 3                                   Cairo, Egypt
# 15                           Copenhagen, Denmark
# 21                   Issy-les-Moulineaux, France
# 25                          Fleet Center, Boston
# 39                           Manila, Philippines
# 51                               Vientiane, Laos
# 52                             Shima City, Japan
# 69                               Santiago, Chile
# 79                             Kingston, Jamaica
# 94                               Yangon, Myanmar
# 115                              Berlin, Germany
# 133                  Clamshell, Bagram Air Field
# 135                                   Lima, Peru
# 151                 Lima Convention Center, Peru
# 161             Teatro Municipal, Rio de Janeiro
# 166                 Parwan Province, Afghanistan
# 178             Ebenezer Baptist Church, Atlanta
# 192                          Brisbane, Australia
# 208                     Westminster Hall, London
# 223                            Shima City, Japan
# 232                               Warsaw, Poland
# 249  Our Lady of Perpetual Help Basilica, Boston
# 262                           Jakarta, Indonesia
# 294                      Cape Town, South Africa
# 301                             New Delhi, India
# 304                          Canberra, Australia
# 309                               Rangoon, Burma
# 324                          Panama City, Panama
# 333                              Hangzhou, China
# 334                          Panama City, Panama
# 340          Elmau Briefing Center Krun, Germany
# 357                            Jerusalem, Israel
# 377                                 Seoul, Korea
# 378                               Ankara, Turkey
# 385          Anthropological Museum, Mexico City
# 389         Nordea Concert Hall Tallinn, Estonia
# 393                    Ho Chi Minh City, Vietnam
# 403                             Normandy, France
# 426                             Hiroshima, Japan

# %%
countries = df.loc[df.title.isin(titles), 'location'].str.extract(r".+?, *(.+)", flags=re.I)
cities = df.loc[df.title.isin(titles), 'location'].str.extract(r" *(.+?),.+", flags=re.I)

df.loc[df.title.isin(titles), 'country']  = countries.values
df.loc[df.title.isin(titles), 'state']  = 'no_state'
df.loc[df.title.isin(titles), 'city']  = cities.values
df.loc[df.title.isin(titles), 'specific_location'] = 'no_specific_location'

# %% [markdown]
# some corrections

# %%
df.loc[df.title=='2004_DNC_Address', 
       ['country','state','city','specific_location']] = ['USA', 'New York', 'Boston', 'no_specific_location']
df.loc[df.title=='Afghanistan_US_Troops_Bagram', 
       ['country','state','city','specific_location']] = ['Afghanistan', 'no_state', 'Bagram', 'Bagram Air Field']
df.loc[df.title=='Peru_Press_Conference', 
       ['country','state','city','specific_location']] = ['Peru', 'no_state', 'Lima', 'Lima Convention Center']
df.loc[df.title=='Rio_de_Janeiro', 
       ['country','state','city','specific_location']] = ['Brazil', 'no_state', 'Rio de Janeiro', 'Teatro Municipal']
df.loc[df.title=='Bagram_Air_Base_December_2010', 
       ['country','state','city','specific_location']] = ['Afghanistan', 'no_state', 'Bagram', 'Bagram Air Field']
df.loc[df.title=='Ebenezer_Baptist', 
       ['country','state','city','specific_location']] = ['USA', 'Georgia', 'Atlanta', 'Ebenezer Baptist Church']
df.loc[df.title=='British_Parliament', 
       ['country','state','city','specific_location']] = ['England', 'no_state', 'London', 'Westminster Hall']
df.loc[df.title=='Ted_Kennedy_Eulogy', 
       ['country','state','city','specific_location']] = ['USA', 'New York', 'Boston', 'Our Lady of Perpetual Help Basilica']
df.loc[df.title=='Post_G7_Conference_Presser_2015', 
       ['country','state','city','specific_location']] = ['Germany', 'no_state', 'Krun', 'Elmau Briefing Center']
df.loc[df.title=='Mexico_Address', 
       ['country','state','city','specific_location']] = ['Mexico', 'no_state', 'Mexico City', 'Anthropological Museum']
df.loc[df.title=='Estonia_People', 
       ['country','state','city','specific_location']] = ['Estonia', 'no_state', 'Tallinn', 'Nordea Concert Hall']

# %%
df.loc[df.title.isin(titles), ['location','country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#                                         location       country     state  \
# 133                  Clamshell, Bagram Air Field   Afghanistan  no_state
# 166                 Parwan Province, Afghanistan   Afghanistan  no_state
# 192                          Brisbane, Australia     Australia  no_state
# 304                          Canberra, Australia     Australia  no_state
# 161             Teatro Municipal, Rio de Janeiro        Brazil  no_state
# 309                               Rangoon, Burma         Burma  no_state
# 69                               Santiago, Chile         Chile  no_state
# 333                              Hangzhou, China         China  no_state
# 15                           Copenhagen, Denmark       Denmark  no_state
# 3                                   Cairo, Egypt         Egypt  no_state
# 208                     Westminster Hall, London       England  no_state
# 389         Nordea Concert Hall Tallinn, Estonia       Estonia  no_state
# 21                   Issy-les-Moulineaux, France        France  no_state
# 403                             Normandy, France        France  no_state
# 115                              Berlin, Germany       Germany  no_state
# 340          Elmau Briefing Center Krun, Germany       Germany  no_state
# 301                             New Delhi, India         India  no_state
# 262                           Jakarta, Indonesia     Indonesia  no_state
# 357                            Jerusalem, Israel        Israel  no_state
# 79                             Kingston, Jamaica       Jamaica  no_state
# 426                             Hiroshima, Japan         Japan  no_state
# 52                             Shima City, Japan         Japan  no_state
# 223                            Shima City, Japan         Japan  no_state
# 377                                 Seoul, Korea         Korea  no_state
# 51                               Vientiane, Laos          Laos  no_state
# 385          Anthropological Museum, Mexico City        Mexico  no_state
# 94                               Yangon, Myanmar       Myanmar  no_state
# 324                          Panama City, Panama        Panama  no_state
# 334                          Panama City, Panama        Panama  no_state
# 151                 Lima Convention Center, Peru          Peru  no_state
# 135                                   Lima, Peru          Peru  no_state
# 39                           Manila, Philippines   Philippines  no_state
# 232                               Warsaw, Poland        Poland  no_state
# 294                      Cape Town, South Africa  South Africa  no_state
# 378                               Ankara, Turkey        Turkey  no_state
# 178             Ebenezer Baptist Church, Atlanta           USA   Georgia
# 249  Our Lady of Perpetual Help Basilica, Boston           USA  New York
# 25                          Fleet Center, Boston           USA  New York
# 393                    Ho Chi Minh City, Vietnam       Vietnam  no_state
#
#                     city                    specific_location
# 133               Bagram                     Bagram Air Field
# 166               Bagram                     Bagram Air Field
# 192             Brisbane                 no_specific_location
# 304             Canberra                 no_specific_location
# 161       Rio de Janeiro                     Teatro Municipal
# 309              Rangoon                 no_specific_location
# 69              Santiago                 no_specific_location
# 333             Hangzhou                 no_specific_location
# 15            Copenhagen                 no_specific_location
# 3                  Cairo                 no_specific_location
# 208               London                     Westminster Hall
# 389              Tallinn                  Nordea Concert Hall
# 21   Issy-les-Moulineaux                 no_specific_location
# 403             Normandy                 no_specific_location
# 115               Berlin                 no_specific_location
# 340                 Krun                Elmau Briefing Center
# 301            New Delhi                 no_specific_location
# 262              Jakarta                 no_specific_location
# 357            Jerusalem                 no_specific_location
# 79              Kingston                 no_specific_location
# 426            Hiroshima                 no_specific_location
# 52            Shima City                 no_specific_location
# 223           Shima City                 no_specific_location
# 377                Seoul                 no_specific_location
# 51             Vientiane                 no_specific_location
# 385          Mexico City               Anthropological Museum
# 94                Yangon                 no_specific_location
# 324          Panama City                 no_specific_location
# 334          Panama City                 no_specific_location
# 151                 Lima               Lima Convention Center
# 135                 Lima                 no_specific_location
# 39                Manila                 no_specific_location
# 232               Warsaw                 no_specific_location
# 294            Cape Town                 no_specific_location
# 378               Ankara                 no_specific_location
# 178              Atlanta              Ebenezer Baptist Church
# 249               Boston  Our Lady of Perpetual Help Basilica
# 25                Boston                 no_specific_location
# 393     Ho Chi Minh City                 no_specific_location

# %% [markdown]
# ### Two commas

# %%
select = (df.country!="USA") & (df.location!="unknown_location") & (df.count_commas == 2)
titles = df.loc[select, 'title']
df.loc[select, ['title','location']]
# Out:
#                                title  \
# 14     PM_Abe_of_Japan_Joint_Presser
# 16                  People_of_Greece
# 17         India_Speech_at_New_Delhi
# 18           Northern_Ireland_Speech
# 58       Kenya_Civil_Society_Meeting
# 82                  YSEALI_Town_Hall
# 98                             COP21
# 108                    Nobel_Lecture
# 125          Brandenburg_Gate_Speech
# 128   Joint_Presser_with_Raul_Castro
# 167          Korean_War_Armistice_60
# 185            African_Union_Address
# 187       Barack_Obama_-_G-20_Turkey
# 193     G20_Remarks_and_Presser_2009
# 195       Toomas_Ilves_Joint_Presser
# 239                   European_Youth
# 283     Speech_to_the_Vietnam_People
# 290       Civil_Society_Forum_Panama
# 299          Europe_Peoples_Hannover
# 306               Cuba_People_Speech
# 313                      Laos_People
# 316       Moscow_New_Economic_School
# 323  Mandela_Public_Memorial_Address
# 329              Kenya_People_Speech
# 341                 Ghana_Parliament
# 342            Malaysia_Presser_2015
# 343                          DDay_70
# 345                     Odyssey_Dawn
# 347        Iraq_Multinational_Troops
# 374                Canada_Parliament
# 383            YSEALI_Town_Hall_2014
# 388            Polish_Freedom_Day_25
# 408                   Vietnam_YSEALI
# 409             Saudi_Arabia_Presser
# 430            Shimon_Peres_Memorial
# 431              ASEAN_Business_2015
# 433                   YLAI_Town_Hall
#
#                                               location
# 14                        Akasaka Palace, Tokyo, Japan
# 16   Stavros Niarchos Foundation Cultural Center, A...
# 17              Siri Fort Auditorium, New Delhi, India
# 18               Waterfront, Belfast, Northern Ireland
# 58                 Kenyatta University, Nairobi, Kenya
# 82    Yangon University, Rangoon/Yangon, Burma/Myanmar
# 98                           Le Bourget, Paris, France
# 108                       Oslo City Hall, Oslo, Norway
# 125                     Pariser Platz, Berlin, Germany
# 128             Palace of the Revolution, Havana, Cuba
# 167            Korean War Memorial, Seoul, South Korea
# 185  African Union Headquarters, Addis Ababa, Ethiopia
# 187               Kaya Palazzo Resort, Antalya, Turkey
# 193                      Excel Center, London, England
# 195                  Bank of Estonia, Tallinn, Estonia
# 239           Palais des Beaux Arts, Brussels, Belgium
# 283         National Convention Center, Hanoi, Vietnam
# 290               Hotel El Panama, Panama City, Panama
# 299       Hannover Messe Building 35, Hanover, Germany
# 306             Gran Teatro de la Habana, Havana, Cuba
# 313        Lao National Cultural Hall, Vientiane, Laos
# 316                      Gostinny Dvor, Moscow, Russia
# 323  First National Bank Stadium, Johannesburg, Sou...
# 329             Safaricom Indoor Arena, Nairobi, Kenya
# 341  Accra International Conference Center, Accra, ...
# 342               Ritz Carlton, Kuala Lumpur, Malaysia
# 343                      Omaha Beach, Normandy, France
# 345  The Convention Center Brasil 21, Brasilia, Brazil
# 347                       Al Faw Palace, Baghdad, Iraq
# 374           House of Commons Chamber, Ottawa, Canada
# 383       University of Malaya, Kuala Lumpur, Malaysia
# 388                      Castle Square, Warsaw, Poland
# 408   GEM Convention Center, Ho Chi Minh City, Vietnam
# 409               Diriyah Palace, Riyadh, Saudi Arabia
# 430                     Mount Herzl, Jerusalem, Israel
# 431           Shangri-La Hotel, Kuala Lumpur, Malaysia
# 433            Usina Del Arte, Buenos Aires, Argentina

# %%
countries = df.loc[df.title.isin(titles), 'location'].str.extract(r".+?,.+?, *(.+)", flags=re.I)
cities = df.loc[df.title.isin(titles), 'location'].str.extract(r".+?, *(.+?),.+", flags=re.I)
locations = df.loc[df.title.isin(titles), 'location'].str.extract(r" *(.+?),.+?,.+", flags=re.I)

df.loc[df.title.isin(titles), 'country']  = countries.values
df.loc[df.title.isin(titles), 'state']  = 'no_state'
df.loc[df.title.isin(titles), 'city']  = cities.values
df.loc[df.title.isin(titles), 'specific_location'] = locations.values

df.loc[df.title=='YSEALI_Town_Hall', 
       ['country','state','city','specific_location']] = ['Myanmar', 'no_state', 'Yangon', 'Yangon University']

# %%
df.loc[df.title.isin(titles), ['title','location','country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#                                title  \
# 433                   YLAI_Town_Hall
# 239                   European_Youth
# 345                     Odyssey_Dawn
# 374                Canada_Parliament
# 306               Cuba_People_Speech
# 128   Joint_Presser_with_Raul_Castro
# 193     G20_Remarks_and_Presser_2009
# 195       Toomas_Ilves_Joint_Presser
# 185            African_Union_Address
# 343                          DDay_70
# 98                             COP21
# 125          Brandenburg_Gate_Speech
# 299          Europe_Peoples_Hannover
# 341                 Ghana_Parliament
# 16                  People_of_Greece
# 17         India_Speech_at_New_Delhi
# 347        Iraq_Multinational_Troops
# 430            Shimon_Peres_Memorial
# 14     PM_Abe_of_Japan_Joint_Presser
# 58       Kenya_Civil_Society_Meeting
# 329              Kenya_People_Speech
# 313                      Laos_People
# 342            Malaysia_Presser_2015
# 431              ASEAN_Business_2015
# 383            YSEALI_Town_Hall_2014
# 82                  YSEALI_Town_Hall
# 18           Northern_Ireland_Speech
# 108                    Nobel_Lecture
# 290       Civil_Society_Forum_Panama
# 388            Polish_Freedom_Day_25
# 316       Moscow_New_Economic_School
# 409             Saudi_Arabia_Presser
# 323  Mandela_Public_Memorial_Address
# 167          Korean_War_Armistice_60
# 187       Barack_Obama_-_G-20_Turkey
# 283     Speech_to_the_Vietnam_People
# 408                   Vietnam_YSEALI
#
#                                               location           country  \
# 433            Usina Del Arte, Buenos Aires, Argentina         Argentina
# 239           Palais des Beaux Arts, Brussels, Belgium           Belgium
# 345  The Convention Center Brasil 21, Brasilia, Brazil            Brazil
# 374           House of Commons Chamber, Ottawa, Canada            Canada
# 306             Gran Teatro de la Habana, Havana, Cuba              Cuba
# 128             Palace of the Revolution, Havana, Cuba              Cuba
# 193                      Excel Center, London, England           England
# 195                  Bank of Estonia, Tallinn, Estonia           Estonia
# 185  African Union Headquarters, Addis Ababa, Ethiopia          Ethiopia
# 343                      Omaha Beach, Normandy, France            France
# 98                           Le Bourget, Paris, France            France
# 125                     Pariser Platz, Berlin, Germany           Germany
# 299       Hannover Messe Building 35, Hanover, Germany           Germany
# 341  Accra International Conference Center, Accra, ...             Ghana
# 16   Stavros Niarchos Foundation Cultural Center, A...            Greece
# 17              Siri Fort Auditorium, New Delhi, India             India
# 347                       Al Faw Palace, Baghdad, Iraq              Iraq
# 430                     Mount Herzl, Jerusalem, Israel            Israel
# 14                        Akasaka Palace, Tokyo, Japan             Japan
# 58                 Kenyatta University, Nairobi, Kenya             Kenya
# 329             Safaricom Indoor Arena, Nairobi, Kenya             Kenya
# 313        Lao National Cultural Hall, Vientiane, Laos              Laos
# 342               Ritz Carlton, Kuala Lumpur, Malaysia          Malaysia
# 431           Shangri-La Hotel, Kuala Lumpur, Malaysia          Malaysia
# 383       University of Malaya, Kuala Lumpur, Malaysia          Malaysia
# 82    Yangon University, Rangoon/Yangon, Burma/Myanmar           Myanmar
# 18               Waterfront, Belfast, Northern Ireland  Northern Ireland
# 108                       Oslo City Hall, Oslo, Norway            Norway
# 290               Hotel El Panama, Panama City, Panama            Panama
# 388                      Castle Square, Warsaw, Poland            Poland
# 316                      Gostinny Dvor, Moscow, Russia            Russia
# 409               Diriyah Palace, Riyadh, Saudi Arabia      Saudi Arabia
# 323  First National Bank Stadium, Johannesburg, Sou...      South Africa
# 167            Korean War Memorial, Seoul, South Korea       South Korea
# 187               Kaya Palazzo Resort, Antalya, Turkey            Turkey
# 283         National Convention Center, Hanoi, Vietnam           Vietnam
# 408   GEM Convention Center, Ho Chi Minh City, Vietnam           Vietnam
#
#         state              city                            specific_location
# 433  no_state      Buenos Aires                               Usina Del Arte
# 239  no_state          Brussels                        Palais des Beaux Arts
# 345  no_state          Brasilia              The Convention Center Brasil 21
# 374  no_state            Ottawa                     House of Commons Chamber
# 306  no_state            Havana                     Gran Teatro de la Habana
# 128  no_state            Havana                     Palace of the Revolution
# 193  no_state            London                                 Excel Center
# 195  no_state           Tallinn                              Bank of Estonia
# 185  no_state       Addis Ababa                   African Union Headquarters
# 343  no_state          Normandy                                  Omaha Beach
# 98   no_state             Paris                                   Le Bourget
# 125  no_state            Berlin                                Pariser Platz
# 299  no_state           Hanover                   Hannover Messe Building 35
# 341  no_state             Accra        Accra International Conference Center
# 16   no_state            Athens  Stavros Niarchos Foundation Cultural Center
# 17   no_state         New Delhi                         Siri Fort Auditorium
# 347  no_state           Baghdad                                Al Faw Palace
# 430  no_state         Jerusalem                                  Mount Herzl
# 14   no_state             Tokyo                               Akasaka Palace
# 58   no_state           Nairobi                          Kenyatta University
# 329  no_state           Nairobi                       Safaricom Indoor Arena
# 313  no_state         Vientiane                   Lao National Cultural Hall
# 342  no_state      Kuala Lumpur                                 Ritz Carlton
# 431  no_state      Kuala Lumpur                             Shangri-La Hotel
# 383  no_state      Kuala Lumpur                         University of Malaya
# 82   no_state            Yangon                            Yangon University
# 18   no_state           Belfast                                   Waterfront
# 108  no_state              Oslo                               Oslo City Hall
# 290  no_state       Panama City                              Hotel El Panama
# 388  no_state            Warsaw                                Castle Square
# 316  no_state            Moscow                                Gostinny Dvor
# 409  no_state            Riyadh                               Diriyah Palace
# 323  no_state      Johannesburg                  First National Bank Stadium
# 167  no_state             Seoul                          Korean War Memorial
# 187  no_state           Antalya                          Kaya Palazzo Resort
# 283  no_state             Hanoi                   National Convention Center
# 408  no_state  Ho Chi Minh City                        GEM Convention Center

# %% [markdown]
# ### Three commas

# %%
select = (df.country!="USA") & (df.location!="unknown_location") & (df.count_commas == 3)
df.loc[select, ['title','location']]
# Out:
#                 title                                           location
# 261  UK_Young_Leaders  Lindley Hall, Royal Horticulture Halls, London...

# %%
df.loc[df.title=='UK_Young_Leaders', 
       ['country','state','city','specific_location']] = ['England', 'no_state', 'London', 'Lindley Hall, Royal Horticulture Halls']

# %% [markdown]
# ### Result for locations not in USA

# %%
df.loc[(df.country!="USA") & (df.location!="unknown_location"), ['location','country','state','city','specific_location']].sort_values(
    by=['country','state','city','specific_location'])
# Out:
#                                              location      country     state  \
# 133                       Clamshell, Bagram Air Field  Afghanistan  no_state
# 166                      Parwan Province, Afghanistan  Afghanistan  no_state
# 433           Usina Del Arte, Buenos Aires, Argentina    Argentina  no_state
# 192                               Brisbane, Australia    Australia  no_state
# 304                               Canberra, Australia    Australia  no_state
# ..                                                ...          ...       ...
# 378                                    Ankara, Turkey       Turkey  no_state
# 187              Kaya Palazzo Resort, Antalya, Turkey       Turkey  no_state
# 283        National Convention Center, Hanoi, Vietnam      Vietnam  no_state
# 408  GEM Convention Center, Ho Chi Minh City, Vietnam      Vietnam  no_state
# 393                         Ho Chi Minh City, Vietnam      Vietnam  no_state
#
#                  city           specific_location
# 133            Bagram            Bagram Air Field
# 166            Bagram            Bagram Air Field
# 433      Buenos Aires              Usina Del Arte
# 192          Brisbane        no_specific_location
# 304          Canberra        no_specific_location
# ..                ...                         ...
# 378            Ankara        no_specific_location
# 187           Antalya         Kaya Palazzo Resort
# 283             Hanoi  National Convention Center
# 408  Ho Chi Minh City       GEM Convention Center
# 393  Ho Chi Minh City        no_specific_location
#
# [78 rows x 5 columns]

# %% [markdown]
# ## Unknown locations

# %%
print('There are %i unknown locations.' % len(df.loc[df.location=="unknown_location", :]))
# Out:
# There are 89 unknown locations.

# %%
df.loc[df.location=="unknown_location", ['title', 'date', 'content']].sort_values(by='date')
# Out:
#                                                 title       date  \
# 173                         Knox_College_Commencement 2005-06-04
# 279            Senate_Floor_Speech_on_the_Patriot_Act 2005-12-15
# 123  Senate_Floor_Speech_on_Voting_Rights_Act_Renewal 2006-07-20
# 105                Candidate_Exploratory_Announcement 2007-01-16
# 344           Senate_Speech_Iraq_Federalism_Amendment 2007-03-13
# ..                                                ...        ...
# 141                             US_Detainees_Released 2016-01-17
# 66                             Weekly_Address_on_Cuba 2016-02-20
# 248               Barack_Obama_-_ISIL_Update_02-25-16 2016-02-25
# 238        Weekly_Address_Opioid_Addiction_Macklemore 2016-05-14
# 270                       Hillary_Clinton_Endorsement 2016-06-09
#
#                                                content
# 173  Good morning President Taylor, Board of Truste...
# 279  Thank you very much, Mr. President. You know, ...
# 123  Mr. President, I rise today both humbled and h...
# 105  As many of you know, over the last few months ...
# 344  Mr. President, I rise, first, to offer strong ...
# ..                                                 ...
# 141  This is a good day, because, once again, we're...
# 66   Hi, everybody. This week, we made it official ...
# 248  Good evening, everybody. I just met with my Na...
# 238  President Obama: Hi, everybody. I've got a spe...
# 270  For more than a year now, across thousands of ...
#
# [89 rows x 3 columns]

# %% [markdown]
# A lot of them seem to be in Washington D.C., so set everything to these values and make the necessary corrections.

# %%
titles = df.loc[df.location=="unknown_location", 'title'].values
df.loc[df.title.isin(titles), 'country'] = 'USA'
df.loc[df.title.isin(titles), 'state'] = 'no_state'
df.loc[df.title.isin(titles), 'city'] = 'Washington D.C.'
df.loc[df.title.isin(titles), 'specific_location'] = 'no_specific_location'

# %%
temp = df.loc[df.location=="unknown_location", ['title', 'date']].sort_values(by='date')
temp.iloc[80:,:]
# Out:
#                                           title       date
# 131                         Iran_Nuclear_Accord 2015-07-14
# 84                       Burundi_People_Message 2015-11-13
# 311                Counter_ISIL_Campaign_Update 2015-12-14
# 335      Barack_Obama_-_Weekly_Address_01-01-16 2016-01-01
# 141                       US_Detainees_Released 2016-01-17
# 66                       Weekly_Address_on_Cuba 2016-02-20
# 248         Barack_Obama_-_ISIL_Update_02-25-16 2016-02-25
# 238  Weekly_Address_Opioid_Addiction_Macklemore 2016-05-14
# 270                 Hillary_Clinton_Endorsement 2016-06-09

# %% [markdown]
# Need corrections.

# %%
need_corrections = ['Knox_College_Commencement','Notre_Dame_Commencement','Buchenwald_Concentration_Camp',
                    'Health_Care_George_Mason','START_Treaty_Presser','Michigan_University_Commencement',
                    'Kalamazoo_HS_Commencement','Pensacola_Military_Personnel','Nurses_Association',
                    'Disabled_Veterans_Conference','GW_Fiscal_Policy','Fort_Campbell',
                    'Clinton_Global_Initiative_Human_Trafficking']

countries = ['USA','USA','Germany','USA','Czech Republic','USA','USA','USA','USA','USA','USA','USA','USA']
states = ['Illinois','Indiana','no_state','Virginia','no_state','Michigan','Michigan','Florida','Maryland',
          'Georgia','no_state','Kentucky','New York']
cities = ['Galesburg','Notre Dame','Thuringia','Fairfax County','Prague','Ann Arbor','Kalamazoo','Pensacola',
          'Silver Spring','Atlanta','Washington D.C.','Hopkinsville','New York']
locations = ['Knox College','Notre Dame University','Buchenwald Concentration Camp','George Mason University',
             'no_specific_location','Michigan University','Kalamazoo Central High School',
             'Pensacola Military Station','American Nurses Association',
             'Disabled Veterans of America Conference','George Washington University','Fort Campbell',
             'Clinton Global Initiative on Human Trafficking']

df.loc[df.title.isin(need_corrections), 'country'] = countries
df.loc[df.title.isin(need_corrections), 'state'] = states
df.loc[df.title.isin(need_corrections), 'city'] = cities
df.loc[df.title.isin(need_corrections), 'specific_location'] = locations
df.loc[df.title.isin(need_corrections), ['country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#             country     state             city  \
# 119  Czech Republic  no_state           Prague
# 113         Germany  no_state        Thuringia
# 206             USA   Florida        Pensacola
# 365             USA   Georgia          Atlanta
# 36              USA  Illinois        Galesburg
# 85              USA   Indiana       Notre Dame
# 427             USA  Kentucky     Hopkinsville
# 210             USA  Maryland    Silver Spring
# 136             USA  Michigan        Ann Arbor
# 173             USA  Michigan        Kalamazoo
# 435             USA  New York         New York
# 118             USA  Virginia   Fairfax County
# 384             USA  no_state  Washington D.C.
#
#                                   specific_location
# 119                            no_specific_location
# 113                   Buchenwald Concentration Camp
# 206                      Pensacola Military Station
# 365         Disabled Veterans of America Conference
# 36                                     Knox College
# 85                            Notre Dame University
# 427                                   Fort Campbell
# 210                     American Nurses Association
# 136                             Michigan University
# 173                   Kalamazoo Central High School
# 435  Clinton Global Initiative on Human Trafficking
# 118                         George Mason University
# 384                    George Washington University

# %% [markdown]
# Were correct, add specific location where possible.

# %%
whitehouse = ['Barack_Obama_-_Al-Arabiya_Interview','Third_Major_Press_Conference','Dignity_and_Courage_of_Iranians',
              'Regina_Benjamin_Nomination','Kennedy_Center_Honorees_2009','Aviation_Security','Finance_Crisis_Fee',
              'Auschwitz_and_Birkenau_Liberation_65th','Prayer_Breakfast_2010','Presser_Unannounced_Heath_Care',
              'No_Child_Left_Behind_Blueprint','Health_Care_Bill_Passage',
              'Justice_Stevens_and_West_Virginia_Mining_Tragedy','Elena_Kagan_USSC_Nomination','UN_Iran_Sanctions',
              'General_McChrystal_Afghanistan','Midterm_Elections_Presser_2010','Tax_Presser','Egypt_History_Revolution',
              'Libya_Violence_Must_Stop','Address_on_Libya','Osama_bin_Laden_Death','David_Petraeus_Etc_Presser',
              'Sandy_Hook_Elementary_School','Final_First_Term_Presser','Gun_Violence_Exec_Order_23',
              'Boston_Marathon_Bombing_First_Statement','Boston_Marathon_Bombing_Second_Statement',
              'Boston_Marathon_Bombing_Third_Statement','Trayvon_Martin','Intelligence_Reform_Presser',
              'Affordable_Care_Act_Modifications_Presser','Iran_Accord_Statement','On_the_Passing_of_Nelson_Mandela',
              'Year_End_Presser_2013','Border_Security_and_Immigration_Reform','MH_Flight_17_Downing',
              'SSG_Bryan_Pitts_MOH','Presser_on_the_Economy_and_Foreign_Policy','Iraq_and_Ukraine','ISIL_',
              'Fixing_Immigration_Policy','Cuba_Policy_Changes','Final_Presser_of_2014',
              'Barack_Obama_-_Weekly_Address_01-01-16','State_of_the_Union_2015','ISIL_Force_Authorization_Request',
              'Iran_Nuclear_Accord','Burundi_People_Message','US_Detainees_Released','Weekly_Address_on_Cuba',
              'Weekly_Address_Opioid_Addiction_Macklemore']

add_loc = ['Senate_Floor_Speech_on_the_Patriot_Act','Senate_Floor_Speech_on_Voting_Rights_Act_Renewal',
            'Senate_Speech_Iraq_Federalism_Amendment','Senate_Floor_Speech_on_Wall_Street_Bailout_Bill',
            'State_of_the_Nation_2009','To_Congress_on_Health_Care','2010_Budget_to_Congress',
            'Hispanic_Chamber_of_Commerce','Democrat_Caucus_Health_Care','911_Pentagon_Memorial_2010',
            'Counter_ISIL_Campaign_Update']

locations = ['Senate','Senate','Senate','Senate','Congress','Congress','Congress','Hispanic Chamber of Commerce',
             'The Capitol','Pentagon','Pentagon']

df.loc[df.title.isin(whitehouse), 'specific_location'] = 'White House'
df.loc[df.title.isin(add_loc), 'specific_location'] = locations
df.loc[df.title.isin(add_loc), ['country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#     country     state             city             specific_location
# 281     USA  no_state  Washington D.C.                      Congress
# 295     USA  no_state  Washington D.C.                      Congress
# 303     USA  no_state  Washington D.C.                      Congress
# 311     USA  no_state  Washington D.C.  Hispanic Chamber of Commerce
# 352     USA  no_state  Washington D.C.                      Pentagon
# 411     USA  no_state  Washington D.C.                      Pentagon
# 70      USA  no_state  Washington D.C.                        Senate
# 123     USA  no_state  Washington D.C.                        Senate
# 138     USA  no_state  Washington D.C.                        Senate
# 279     USA  no_state  Washington D.C.                        Senate
# 344     USA  no_state  Washington D.C.                   The Capitol

# %% [markdown]
# Assumed to be correct, but not entirely known: Candidate_Exploratory_Announcement, Global_Climate_Message, Regina_Benjamin_Nomination, Kennedy_Center_Honorees_2009, Finance_Crisis_Fee,Health_Care_Bill_Passage, Justice_Stevens_and_West_Virginia_Mining_Tragedy, Elena_Kagan_USSC_Nomination, Nurses_Association, Egypt_History_Revolution, Libya_Violence_Must_Stop, Hillary_Clinton_Endorsement

# %%
df.loc[df.title.isin(titles), ['country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location'])
# Out:
#             country     state             city  \
# 119  Czech Republic  no_state           Prague
# 113         Germany  no_state        Thuringia
# 206             USA   Florida        Pensacola
# 365             USA   Georgia          Atlanta
# 36              USA  Illinois        Galesburg
# ..              ...       ...              ...
# 270             USA  no_state  Washington D.C.
# 275             USA  no_state  Washington D.C.
# 277             USA  no_state  Washington D.C.
# 282             USA  no_state  Washington D.C.
# 406             USA  no_state  Washington D.C.
#
#                            specific_location
# 119                     no_specific_location
# 113            Buchenwald Concentration Camp
# 206               Pensacola Military Station
# 365  Disabled Veterans of America Conference
# 36                              Knox College
# ..                                       ...
# 270                     no_specific_location
# 275                     no_specific_location
# 277                     no_specific_location
# 282                     no_specific_location
# 406                     no_specific_location
#
# [89 rows x 4 columns]

# %% [markdown]
# # Completely cleaned data

# %%
df.loc[:, ['title','date','country','state','city','specific_location']].sort_values(
    by= ['country','state','city','specific_location','date'])
# Out:
#                              title       date      country     state  \
# 133   Afghanistan_US_Troops_Bagram 2010-03-28  Afghanistan  no_state
# 166  Bagram_Air_Base_December_2010 2010-12-03  Afghanistan  no_state
# 433                 YLAI_Town_Hall 2016-03-23    Argentina  no_state
# 192          Queensland_University 2014-11-15    Australia  no_state
# 304          Australian_Parliament 2011-11-16    Australia  no_state
# ..                             ...        ...          ...       ...
# 139                  VOX_Interview 2017-01-06          USA  no_state
# 93           Chicago_Cubs_WH_Visit 2017-01-17          USA  no_state
# 283   Speech_to_the_Vietnam_People 2016-05-24      Vietnam  no_state
# 408                 Vietnam_YSEALI 2016-05-25      Vietnam  no_state
# 393        Dreamplex_Event_Address 2016-05-24      Vietnam  no_state
#
#                  city           specific_location
# 133            Bagram            Bagram Air Field
# 166            Bagram            Bagram Air Field
# 433      Buenos Aires              Usina Del Arte
# 192          Brisbane        no_specific_location
# 304          Canberra        no_specific_location
# ..                ...                         ...
# 139   Washington D.C.        no_specific_location
# 93    Washington D.C.        no_specific_location
# 283             Hanoi  National Convention Center
# 408  Ho Chi Minh City       GEM Convention Center
# 393  Ho Chi Minh City        no_specific_location
#
# [436 rows x 6 columns]

# %% [markdown]
# # Make new csv

# %% [markdown]
# Only known locations

# %%
path_only_known = csv_dir / "speeches_loc_known_cleaned.txt"
only_known = df.loc[df.location!="unknown_location", :]
#only_known.to_csv(path_only_known, index=False, header=True, mode='w')

# %% [markdown]
# Fully cleaned

# %%
path = csv_dir / "all_speeches_cleaned.txt"
#df.to_csv(path, index=False, header=True, mode='w')
